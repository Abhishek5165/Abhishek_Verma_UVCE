# %% [markdown]
# # Task 1 : Exploratory Data Analysis (EDA) and Business Insights

# %% [markdown]
# # Import necessary libraries 📲

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the datasets 🖨

# %%
customers    =  pd.read_csv("C:/Users/HP/Desktop/ZeoTap/Data/Customers.csv")
products     =  pd.read_csv("C:/Users/HP/Desktop/ZeoTap/Data/Products.csv")
transactions =  pd.read_csv("C:/Users/HP/Desktop/ZeoTap/Data/Transactions.csv")

# %% [markdown]
# # Understanding the Data 👨🏽‍💻

# %%
customers.head()
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15

# %%
customers.tail()
# Out:
#     CustomerID      CustomerName  Region  SignupDate
# 195      C0196       Laura Watts  Europe  2022-06-07
# 196      C0197  Christina Harvey  Europe  2023-03-21
# 197      C0198       Rebecca Ray  Europe  2022-02-27
# 198      C0199    Andrea Jenkins  Europe  2022-12-03
# 199      C0200       Kelly Cross    Asia  2023-06-11

# %%
customers.shape
# Out:
# (200, 4)

# %%
products.head()
# Out:
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31

# %%
products.tail()
# Out:
#    ProductID             ProductName     Category   Price
# 95      P096    SoundWave Headphones  Electronics  307.47
# 96      P097      BookWorld Cookbook        Books  319.34
# 97      P098        SoundWave Laptop  Electronics  299.93
# 98      P099  SoundWave Mystery Book        Books  354.29
# 99      P100       HomeSense Sweater     Clothing  126.34

# %%
products.shape
# Out:
# (100, 4)

# %%
transactions.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue   Price
# 0      300.68  300.68
# 1      300.68  300.68
# 2      300.68  300.68
# 3      601.36  300.68
# 4      902.04  300.68

# %%
transactions.tail()
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 995      459.86  459.86
# 996     1379.58  459.86
# 997     1839.44  459.86
# 998      919.72  459.86
# 999      459.86  459.86

# %%
transactions.shape
# Out:
# (1000, 7)

# %% [markdown]
# # Merge the Datasets 🤝

# %%
# Merge Transactions with Customers and Products

transactions_customers = pd.merge(transactions, customers, on="CustomerID", how="inner")
merged_data = pd.merge(transactions_customers, products, on="ProductID", how="inner")

# Display the merged dataset
print("Merged Dataset Info:\n")

merged_data.info()
print("\n")
# Out:
# Merged Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 109.4+ KB

# %%
merged_data.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue  Price_x     CustomerName         Region  SignupDate  \
# 0      300.68   300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68   300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68   300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36   300.68  Travis Campbell  South America  2024-04-11
# 4      902.04   300.68    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category  Price_y
# 0  ComfortLiving Bluetooth Speaker  Electronics   300.68
# ...

# %%
merged_data.tail()
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 995        T00630      C0031      P093  2024-10-08 23:58:14         2
# 996        T00672      C0165      P044  2024-07-28 00:09:49         4
# 997        T00711      C0165      P044  2024-06-11 15:51:14         4
# 998        T00878      C0165      P044  2024-09-24 21:15:21         3
# 999        T00157      C0169      P044  2024-11-09 09:07:36         2
#
#      TotalValue  Price_x   CustomerName         Region  SignupDate  \
# 995      609.88   304.94    Tina Miller  South America  2024-04-11
# 996       75.28    18.82  Juan Mcdaniel  South America  2022-04-09
# 997       75.28    18.82  Juan Mcdaniel  South America  2022-04-09
# 998       56.46    18.82  Juan Mcdaniel  South America  2022-04-09
# 999       37.64    18.82  Jennifer Shaw  South America  2023-04-13
#
#                   ProductName    Category  Price_y
# 995              TechPro Vase  Home Decor   304.94
# ...

# %%
merged_data.shape
# Out:
# (1000, 13)

# %%
merged_data.describe()
# Out:
#           Quantity   TotalValue     Price_x     Price_y
# count  1000.000000  1000.000000  1000.00000  1000.00000
# mean      2.537000   689.995560   272.55407   272.55407
# std       1.117981   493.144478   140.73639   140.73639
# min       1.000000    16.080000    16.08000    16.08000
# 25%       2.000000   295.295000   147.95000   147.95000
# 50%       3.000000   588.880000   299.93000   299.93000
# 75%       4.000000  1011.660000   404.40000   404.40000
# max       4.000000  1991.040000   497.76000   497.76000

# %% [markdown]
# # Cleaning the Data 😉

# %%
merged_data.nunique()
# Out:
# TransactionID      1000
# CustomerID          199
# ProductID           100
# TransactionDate    1000
# Quantity              4
# TotalValue          369
# Price_x             100
# CustomerName        199
# Region                4
# SignupDate          178
# ProductName          66
# Category              4
# Price_y             100
# dtype: int64

# %%
merged_data.isnull().sum()
# Out:
# TransactionID      0
# CustomerID         0
# ProductID          0
# TransactionDate    0
# Quantity           0
# TotalValue         0
# Price_x            0
# CustomerName       0
# Region             0
# SignupDate         0
# ProductName        0
# Category           0
# Price_y            0
# dtype: int64

# %%
# Convert date columns to datetime format

customers['SignupDate'] = pd.to_datetime(customers['SignupDate'])
transactions['TransactionDate'] = pd.to_datetime(transactions['TransactionDate'])

# Check for duplicates

print("Duplicate rows in Customers:", customers.duplicated().sum())
print("Duplicate rows in Products:", products.duplicated().sum())
print("Duplicate rows in Transactions:", transactions.duplicated().sum())
# Out:
# Duplicate rows in Customers: 0
# Duplicate rows in Products: 0
# Duplicate rows in Transactions: 0

# %% [markdown]
# # Exploratory Data Analysis (EDA) 👇

# %% [markdown]
# ## Relationship analysis between Variables

# %%
## Analyze Customer Distribution by Region

region_counts = customers['Region'].value_counts()
print("\nCustomer Distribution by Region:\n",region_counts)
# Out:
# Customer Distribution by Region:
#  South America    59
# Europe           50
# North America    46
# Asia             45
# Name: Region, dtype: int64

# %% [markdown]
# ## Regional Analysis

# %%
## Visualization: Customer Distribution by Region (bar plot) - 

colors = sns.color_palette("magma", len(region_counts))
plt.figure(figsize=(8, 5))
plt.bar(region_counts.index, region_counts.values, color=colors)
plt.title("Customer Distribution by Region", fontsize=14)
plt.xlabel("\nRegion", fontsize=12)
plt.ylabel("Number of Customers", fontsize=12)
plt.show()

# %%
# Convert date columns to datetime format

merged_data['SignupDate'] = pd.to_datetime(merged_data['SignupDate'])

# %%
## Analyze Signup Trends Over Time

merged_data['YearMonth'] = merged_data['SignupDate'].dt.to_period('M')
signup_trends = merged_data['YearMonth'].value_counts().sort_index()
print("\nSignup Trends Over Time (First 5 Rows):\n", signup_trends.head())
# Out:
# Signup Trends Over Time (First 5 Rows):
#  2022-01     6
# 2022-02    34
# 2022-03    46
# 2022-04    42
# 2022-05    57
# Freq: M, Name: YearMonth, dtype: int64

# %%
## Visualization: Signup Trends Over Time

plt.figure(figsize=(10, 6))
signup_trends.plot(kind='line', marker='o', color='r', linewidth=2)
plt.title("Customer Signup Trends Over Time", fontsize=14)
plt.xlabel("Year-Month", fontsize=12)
plt.ylabel("Number of Signups", fontsize=12)
plt.grid(alpha=0.5)
plt.show()

# %%
## Analyze Monthly Signup Trends

monthly_signups = merged_data['SignupDate'].dt.month.value_counts().sort_index()
print("\nMonthly Signup Trends:\n", monthly_signups)
# Out:
# Monthly Signup Trends:
#  1      79
# 2      99
# 3     100
# 4     122
# 5     107
# 6      54
# 7      63
# 8      47
# 9     111
# 10     80
# 11     76
# 12     62
# Name: SignupDate, dtype: int64

# %% [markdown]
# ## Monthly Trends

# %%
# Visualization: Monthly Signup Trends

colors = sns.color_palette("viridis", len(monthly_signups))

plt.figure(figsize=(8, 5))
plt.bar(range(len(monthly_signups)), monthly_signups.values, color=colors)
plt.xticks(range(len(monthly_signups)), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)

# Add titles and labels
plt.title("Monthly Signup Trends", fontsize=14)
plt.xlabel("\nMonth", fontsize=12)
plt.ylabel("Number of Signups", fontsize=12)

plt.show()

# %%
## Analyze Yearly Signup Growth

merged_data['Year'] = merged_data['SignupDate'].dt.year
yearly_growth = merged_data['Year'].value_counts().sort_index()
print("\nYearly Signup Growth:\n", yearly_growth)
# Out:
# Yearly Signup Growth:
#  2022    332
# 2023    281
# 2024    387
# Name: Year, dtype: int64

# %% [markdown]
# ## Yearly Trends

# %%
## Visualization: Yearly Signup Trends

custom_colors = ["black","coral","purple"]

plt.figure(figsize=(8, 5))
plt.bar(range(len(yearly_growth)), yearly_growth.values, color=custom_colors) 
plt.xticks(range(len(yearly_growth)), yearly_growth.index) 

## Add titles and labels
plt.title("Yearly Signup Trends", fontsize=14)
plt.xlabel("\nYear", fontsize=12)
plt.ylabel("Number of Signups", fontsize=12)
plt.show()

# %%
# Distribution of Price

plt.figure(figsize=(8, 5))
sns.histplot(products['Price'], bins=30, kde=True, color='blue')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Product Category Analysis

# %%
# Transaction count and sales by category

category_counts = merged_data['Category'].value_counts()
category_sales = merged_data.groupby('Category')['TotalValue'].sum().sort_values(ascending=False)

# Plot transaction count by category

custom_palette = sns.color_palette(["grey", "red","blue","green"])

plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, hue=category_counts.index, palette=custom_palette)
plt.title("\nTransaction Count by Product Category", fontsize=16)
plt.xlabel("\nCategory", fontsize=12)
plt.ylabel("Transaction Count", fontsize=12)
plt.legend([], [], frameon=False)
plt.tight_layout()
plt.show()

# Plot total sales by category

plt.figure(figsize=(8, 6))
sns.barplot(x=category_sales.index, y=category_sales.values, hue=category_sales.index, palette=custom_palette)
plt.title("\nTotal Sales by Product Category", fontsize=16)
plt.xlabel("\nCategory", fontsize=12)
plt.ylabel("Total Sales Value", fontsize=12)
plt.legend([], [], frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly Transactions Trends

# %%
# Customer distribution by region

region_counts = merged_data['Region'].value_counts()

# Generate a color palette
colors = sns.color_palette("cividis", len(region_counts))

# Plot regional distribution
plt.figure(figsize=(8, 6))
plt.bar(region_counts.index, region_counts.values, color=colors) 
plt.title("Customer Distribution by Region", fontsize=16)
plt.xlabel("Region", fontsize=12)
plt.ylabel("Number of Transactions", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Convert 'TransactionDate' to datetime format
merged_data['TransactionDate'] = pd.to_datetime(merged_data['TransactionDate'], errors='coerce')

# Check for any invalid date conversions
invalid_dates = merged_data['TransactionDate'].isna().sum()
print(f"Number of invalid dates: {invalid_dates}")

# Extract month from TransactionDate
merged_data['TransactionMonth'] = merged_data['TransactionDate'].dt.to_period('M')

# Monthly transaction count and total sales
monthly_counts = merged_data['TransactionMonth'].value_counts().sort_index()
monthly_sales = merged_data.groupby('TransactionMonth')['TotalValue'].sum()

# Plot monthly transaction count
plt.figure(figsize=(10, 6))
monthly_counts.plot(kind='bar', color='blue', alpha=0.7)
plt.title("Monthly Transaction Count", fontsize=16)
plt.xlabel("\nMonth", fontsize=12)
plt.ylabel("Transaction Count", fontsize=12)
plt.tight_layout()
plt.show()

# Plot monthly total sales
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='bar', color='orange', alpha=0.7)
plt.title("Monthly Total Sales", fontsize=16)
plt.xlabel("\nMonth", fontsize=12)
plt.ylabel("Total Sales Value", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Number of invalid dates: 0

# %%
# Top 10 products by transaction count

plt.figure(figsize=(10, 6))
colors = sns.color_palette("viridis", len(top_products_count))  
plt.barh(top_products_count.index, top_products_count.values, color=colors)  
plt.title("Top 10 Products by Transaction Count", fontsize=16)
plt.xlabel("\nTransaction Count", fontsize=12)
plt.ylabel("Product Name", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 products by total sales

plt.figure(figsize=(10, 6))
colors = sns.color_palette("viridis", len(top_products_sales))
plt.barh(top_products_sales.index, top_products_sales.values, color=colors)
plt.title("Top 10 Products by Total Sales", fontsize=16)
plt.xlabel("\nTotal Sales Value", fontsize=12)
plt.ylabel("Product Name", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving the Final merged File

# %%
# Save the merged data

merged_data.to_csv('Merged_Data.csv', index=False)
print("Merged data saved as 'Merged_Data.csv'")
# Out:
# Merged data saved as 'Merged_Data.csv'

# %% [markdown]
# ## Top business insights from Above EDA Analysis

# %% [markdown]
# ### 1. Regional Performance

# %%
# Print the customer distribution by region
print("Customer Distribution by Region:\n", region_counts)
# Out:
# Customer Distribution by Region:
#  South America    304
# North America    244
# Europe           234
# Asia             218
# Name: Region, dtype: int64

# %% [markdown]
# ### 2. Category Contribution

# %%
# Print transaction count and total sales by category

print("Transaction Count by Category:\n", category_counts)
print("\nTotal Sales by Category:\n", category_sales)
# Out:
# Transaction Count by Category:
#  Books          270
# Electronics    254
# Home Decor     248
# Clothing       228
# Name: Category, dtype: int64
#
# Total Sales by Category:
#  Category
# Books          192147.47
# Electronics    180783.50
# Clothing       166170.66
# Home Decor     150893.93
# Name: TotalValue, dtype: float64

# %% [markdown]
# ### 3. Seasonal Trends

# %%
# Print monthly transaction count
print("Monthly Transaction Counts:\n", monthly_counts)

# Print monthly total sales
print("\nMonthly Total Sales:\n", monthly_sales)
# Out:
# Monthly Transaction Counts:
#  2023-12      4
# 2024-01    107
# 2024-02     77
# 2024-03     80
# 2024-04     86
# 2024-05     86
# 2024-06     69
# 2024-07     96
# 2024-08     94
# 2024-09     96
# 2024-10     70
# 2024-11     57
# 2024-12     78
# Freq: M, Name: TransactionMonth, dtype: int64
#
# Monthly Total Sales:
#  TransactionMonth
# 2023-12     3769.52
# 2024-01    66376.39
# 2024-02    51459.27
# 2024-03    47828.73
# 2024-04    57519.06
# 2024-05    64527.74
# 2024-06    48771.18
# 2024-07    71366.39
# 2024-08    63436.74
# 2024-09    70603.75
# 2024-10    47063.22
# 2024-11    38224.37
# 2024-12    59049.20
# Freq: M, Name: TotalValue, dtype: float64

# %% [markdown]
# ### 4. Product-Level Insights

# %%
# Top 10 products by transaction count
top_products_count = merged_data['ProductName'].value_counts().head(10)

# Top 10 products by total sales
top_products_sales = (
    merged_data.groupby('ProductName')['TotalValue'].sum()
    .sort_values(ascending=False)
    .head(10)
)

# Print top 10 products by transaction count
print("Top 10 Products by Transaction Count:\n", top_products_count)

# Print top 10 products by total sales
print("\nTop 10 Products by Total Sales:\n", top_products_sales)
# Out:
# Top 10 Products by Transaction Count:
#  ActiveWear Smartwatch    40
# SoundWave Headphones     38
# BookWorld Biography      30
# ActiveWear Rug           29
# SoundWave Cookbook       29
# HomeSense Desk Lamp      28
# ActiveWear Jacket        26
# TechPro Textbook         25
# TechPro T-Shirt          24
# ActiveWear Textbook      23
# Name: ProductName, dtype: int64
#
# Top 10 Products by Total Sales:
#  ProductName
# ActiveWear Smartwatch      39096.97
# SoundWave Headphones       25211.64
# SoundWave Novel            24507.90
# ActiveWear Jacket          22712.56
# ActiveWear Rug             22314.43
# TechPro Headphones         19513.80
# BookWorld Cookbook         19221.99
# BookWorld Sweater          18743.79
# TechPro Textbook           18267.96
# ActiveWear Cookware Set    18083.73
# Name: TotalValue, dtype: float64

# %% [markdown]
# ### 5. Customer Signup Trends

# %%
# Verify the signup_trends data
print("Customer Signup Trends:\n", signup_trends)
# Out:
# Customer Signup Trends:
#  2022-01     6
# 2022-02    34
# 2022-03    46
# 2022-04    42
# 2022-05    57
# 2022-06    24
# 2022-07    15
# 2022-08    13
# 2022-09    30
# 2022-10    22
# 2022-11    14
# 2022-12    29
# 2023-01    30
# 2023-02    30
# 2023-03    34
# 2023-04    32
# 2023-05    16
# 2023-06    16
# 2023-07    12
# 2023-08    14
# 2023-09    23
# 2023-10    27
# 2023-11    19
# 2023-12    28
# 2024-01    43
# 2024-02    35
# 2024-03    20
# 2024-04    48
# 2024-05    34
# 2024-06    14
# 2024-07    36
# 2024-08    20
# 2024-09    58
# 2024-10    31
# 2024-11    43
# 2024-12     5
# Freq: M, Name: YearMonth, dtype: int64

# %% [markdown]
# # Thank You !
